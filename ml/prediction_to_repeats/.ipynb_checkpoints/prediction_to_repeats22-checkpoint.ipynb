# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import tqdm # interactive progress bar

plt.style.use('ggplot')
# %matplotlib inline

# %%
# help(pd.read_csv)
url_to_data = 'data/data_fromAug2017.csv'
data = pd.read_csv(url_to_data, names=['CLIENT_CATEGORY', 'SEGMENT', 'Service', 'Channeltype', 'Source', 'football',
'DECLARED_FAULT', 'CREATE_DATE', 'CLOSETIME', 'all_num_of_repeat', 'num_of_repeat2', 'num_of_repeat5', 'num_of_repeat10',
'num_of_repeat30', 'num_of_repeat60', 'MITYPE', 'MIPRIORITY', 'MIIMPACT', 'TECHNICAL_DISTRICT', 'NumWFMforEI',
'Last_WFM_days_waiting', 'EIDayOfWeek', 'EIHourCreate'], na_values='0', delimiter=';', skiprows=[0])

# %%
data.shape
# Out:
# (9637, 22)

# %%
# data.columns=['A' + str(i) for i in range(len(data.columns))]
# data.head()

# %%
# data.describe()

# %%
# extract categorical and numerical features
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print('Categorical columns: ', categorical_columns)
print('Numerical columns: ', numerical_columns)
# Out:
# Categorical columns:  ['CLIENT_CATEGORY', 'SEGMENT', 'DECLARED_FAULT']
# Numerical columns:  ['Service', 'Channeltype', 'Source', 'football', 'CREATE_DATE', 'CLOSETIME', 'all_num_of_repeat', 'num_of_repeat2', 'num_of_repeat5', 'num_of_repeat10', 'num_of_repeat30', 'num_of_repeat60', 'MITYPE', 'MIPRIORITY', 'MIIMPACT', 'NumWFMforEI', 'TECHNICAL_DISTRICT', 'EIDayOfWeek', 'EIHourCreate']

# %%
data[numerical_columns].describe()
# Out:
#            Service   Channeltype        Source     football   CREATE_DATE  \
# count  9637.000000   8632.000000   9637.000000  9637.000000  9.637000e+03
# mean   8793.888555   9288.238531   8689.607243     3.436962  1.502999e+09
# std     314.066338    319.542144    388.953144     1.462090  2.180252e+05
# min    8676.000000   9203.000000   7470.000000     1.000000  1.502669e+09
# 25%    8678.000000   9204.000000   8750.000000     3.000000  1.502804e+09
# 50%    8678.000000   9204.000000   8750.000000     3.000000  1.502967e+09
# 75%    8680.000000   9204.000000   8750.000000     4.000000  1.503176e+09
# max    9650.000000  10769.000000  10867.000000    29.000000  1.503414e+09
#
#           CLOSETIME  all_num_of_repeat  num_of_repeat2  num_of_repeat5  \
# count  9.637000e+03        8570.000000     1838.000000     4206.000000
# mean   1.503047e+09           2.158576        1.057127        1.091774
# std    2.162802e+05           2.944611        0.243591        0.329514
# min    1.502686e+09           1.000000        1.000000        1.000000
# 25%    1.502875e+09           1.000000        1.000000        1.000000
# 50%    1.503023e+09           1.000000        1.000000        1.000000
# 75%    1.503234e+09           2.000000        1.000000        1.000000
# max    1.503414e+09          96.000000        3.000000        4.000000
#
#        num_of_repeat10  num_of_repeat30  num_of_repeat60      MITYPE  \
# count      8570.000000      8570.000000      8570.000000  311.000000
# mean          1.134539         1.238040         1.348191    1.070740
# std           0.404473         0.588964         0.805874    0.515701
# min           1.000000         1.000000         1.000000    1.000000
# 25%           1.000000         1.000000         1.000000    1.000000
# 50%           1.000000         1.000000         1.000000    1.000000
# 75%           1.000000         1.000000         1.000000    1.000000
# max           5.000000         9.000000        13.000000    6.000000
#
#        MIPRIORITY    MIIMPACT  NumWFMforEI  TECHNICAL_DISTRICT  EIDayOfWeek  \
# count  250.000000  247.000000  6216.000000         6216.000000  9637.000000
# mean     2.916000    2.919028     1.032819           34.947716     3.583999
# std      0.996452    0.967733     0.183514            8.866544     1.737114
# min      1.000000    1.000000     1.000000            3.000000     1.000000
# 25%      3.000000    3.000000     1.000000           28.000000     2.000000
# 50%      3.000000    3.000000     1.000000           36.000000     3.000000
# 75%      4.000000    4.000000     1.000000           42.000000     5.000000
# max      5.000000    4.000000     3.000000           64.000000     7.000000
#
#        EIHourCreate
# count   9548.000000
# mean      14.297968
# std        4.089310
# min        1.000000
# 25%       11.000000
# 50%       14.000000
# 75%       17.000000
# max       23.000000

# %%
data[categorical_columns].describe() # Stats for categorial features
# Out:
#        CLIENT_CATEGORY SEGMENT                           DECLARED_FAULT
# count             9591    9633                                     9637
# unique              27       6                                      178
# top                 ФЛ      МР  Телефония. Тишина в трубке, нет зуммера
# freq              7229    7478                                      932

# %%
# data.describe(include=[object]) # Another way to do the same

# %%
## Legends
LEGEND={'Channeltype':{
'9207':'Медная линия',
'9205':'Канальная АТШ',
'9204': 'Канальная PON',
'9986':'Канальная Radio',
'9206':'Кодер видеонаблюдения',
'9636':'IP ОПС',
'9987':'Канальная Радио (юрики)',
'9203':'Канал ADSL',
'9633':'Канальная FTTB',
'9632':'ОПС',
'9202':'Камера видеонаблюдения',
'10769':'Канальная МЕДЬ',
'9197':'RFC PON',
'9198':'RFC АТШ',
'9199':'Интернет PON',
'9200':'Интернет АТШ',
'9201':'Интернет АТШ (юрики)',
'9208':'Телевидение PON',
'9209':'Телевидение АТШ',
'9210':'Телефон PON',
'9211':'Телефон АТШ',
'9212':'УПАТС PON',
'9630':'Телефон FTTB',
'9631':'Телевидение FTTB',
'9634':'Интернет FTTB',
'9635':'RFC FTTB'},
'Service':{
'9650':'Все сервисы',
'9697':'ОПС',
'8677':'Не сетевой инцидент',
'8679':'Телевидение',
'8681':'Технологические сервисы',
'8676':'Дополнительные сервисы',
'8678':'Передача данных',
'8680':'Телефония',
'8682':'Энергетическое и климатическое обеспечение технологических площадок'}}

# %%
stats=dict()
stat=dict()
for i in ['CLIENT_CATEGORY', 'SEGMENT', 'DECLARED_FAULT', 'Service', 'Channeltype', 'football', 'TECHNICAL_DISTRICT',
          'EIDayOfWeek', 'EIHourCreate']:
    stats[i]=data[i].value_counts()
    stat[i]=pd.Series(stats[i])
# print(stats.keys())
# print(stats['Service'])
stats['Service']
# Out:
# 8678    5061
# 8680    2432
# 9650    1143
# 8679     963
# 8677      16
# 8681      11
# 8676      11
# Name: Service, dtype: int64

# %%
stats['CLIENT_CATEGORY'].values
# Out:
# array([7229,  812,  229,  222,  210,  190,  121,  121,   94,   68,   62,
#          48,   46,   26,   22,   21,   19,   13,   12,    9,    8,    3,
#           2,    1,    1,    1,    1], dtype=int64)

# %%
LEGEND['Channeltype'].keys()
# Out:
# dict_keys(['9207', '9205', '9204', '9986', '9206', '9636', '9987', '9203', '9633', '9632', '9202', '10769', '9197', '9198', '9199', '9200', '9201', '9208', '9209', '9210', '9211', '9212', '9630', '9631', '9634', '9635'])

# %%
cat_features=set()
for feature in sorted(stats.keys()):
    d_first=20
#     print(len(stats[feature]))
    if len(stats[feature])< 20:
        d_first = len(stats[feature])
    print("\n"+feature+"\n")
    for i in stats[feature].keys()[:d_first]:
        if type(i) == str:
            print(stats[feature][i], "\t", i)
        else:
            cat_features.add(feature)
# print(cat_features)
if cat_features:
    for feature in cat_features:
        try:
            if LEGEND[feature]:
            
                print("\n", feature, "\n")
                for i in stats[feature].keys():
                    print(stats[feature][i], "\t", LEGEND[feature][str(int(i))])
        except:
                pass
#     print(stats[feature].keys()[:d_first], stats[feature].values[:d_first])
# Out:
# CLIENT_CATEGORY
#
# 7229 	 ФЛ
# 812 	 SOHO
# 229 	 Выделенное обслуживание (пилот)
# 222 	 NKA
# 210 	 SME
# 190 	 GS-SLA4
# 121 	 SME GS
# 121 	 Оператор
# 94 	 Corporate
# 68 	 GS-SLA1
# 62 	 SOHO_GS
# 48 	 KA
# 46 	 Corporate GS
# 26 	 KA GS
# 22 	 Имидж-абоненты (физические лица)
# 21 	 GS-Имидж абоненты
# 19 	 GS-SLA3
# 13 	 Развитие
# 12 	 INDIVIDUAL
# 9 	 СПЕЦ
#
# Channeltype
#
#
# DECLARED_FAULT
#
# 932 	 Телефония. Тишина в трубке, нет зуммера
# 751 	 Телефония. Тишина в трубке
# 751 	 ONT не на линии. Проблема с оптическим кабелем
# 566 	 Интернет. Не работает интернет
# 423 	 Не работает ONT. Нет индикации питания.
# 411 	 ТВ. Не получен IP-адрес
# 388 	 Интернет. Не открываются все страницы
# 352 	 ТВ. Черный или синий экран
# 300 	 ТВ. Проблемы с пультом
# 224 	 Swap ONT Huawei
# 215 	 Телефония. Зуммер занято
# 210 	 SLX_Не работает INTERNET
# 208 	 Интернет. Другое
# 198 	 ONT на линии. Высокое затухание
# 182 	 Перенос/замена модели ONT
# 170 	 ТВ. Другое
# 162 	 Интернет. Не открываются страницы
# 155 	 ТВ. Рассыпание/замирание
# 139 	 Телефония. Не работает входящая связь
# 134 	 ТВ. Ошибка при активации приставки
#
# EIDayOfWeek
#
#
# EIHourCreate
#
#
# SEGMENT
#
# 7478 	 МР
# 1831 	 КОРП
# 258 	 ГОС
# 37 	 Оператор
# 28 	 БС28
# 1 	 Внутренний
#
# Service
#
#
# TECHNICAL_DISTRICT
#
#
# football
#
#
#  Service
#
# 5061 	 Передача данных
# 2432 	 Телефония
# 1143 	 Все сервисы
# 963 	 Телевидение
# 16 	 Не сетевой инцидент
# 11 	 Технологические сервисы
# 11 	 Дополнительные сервисы
#
#  Channeltype
#
# 6401 	 Канальная PON
# 1307 	 Канальная АТШ
# 397 	 Канальная FTTB
# 355 	 Канальная МЕДЬ
# 141 	 Канал ADSL
# 31 	 Медная линия

# %%
stats['SEGMENT'][:6].plot()

# %%
# data.head()

# %%
for i in data:
    print(data[i].describe())
# Out:
# count     9591
# unique      27
# top         ФЛ
# freq      7229
# Name: CLIENT_CATEGORY, dtype: object
# count     9633
# unique       6
# top         МР
# freq      7478
# Name: SEGMENT, dtype: object
# count    9637.000000
# mean     8793.888555
# std       314.066338
# min      8676.000000
# 25%      8678.000000
# 50%      8678.000000
# 75%      8680.000000
# max      9650.000000
# Name: Service, dtype: float64
# count     8632.000000
# mean      9288.238531
# std        319.542144
# min       9203.000000
# 25%       9204.000000
# 50%       9204.000000
# 75%       9204.000000
# max      10769.000000
# Name: Channeltype, dtype: float64
# count     9637.000000
# mean      8689.607243
# std        388.953144
# min       7470.000000
# 25%       8750.000000
# 50%       8750.000000
# 75%       8750.000000
# max      10867.000000
# Name: Source, dtype: float64
# count    9637.000000
# mean        3.436962
# std         1.462090
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max        29.000000
# Name: football, dtype: float64
# count                                        9637
# unique                                        178
# top       Телефония. Тишина в трубке, нет зуммера
# freq                                          932
# Name: DECLARED_FAULT, dtype: object
# count    9.637000e+03
# mean     1.502999e+09
# std      2.180252e+05
# min      1.502669e+09
# 25%      1.502804e+09
# 50%      1.502967e+09
# 75%      1.503176e+09
# max      1.503414e+09
# Name: CREATE_DATE, dtype: float64
# count    9.637000e+03
# mean     1.503047e+09
# std      2.162802e+05
# min      1.502686e+09
# 25%      1.502875e+09
# 50%      1.503023e+09
# 75%      1.503234e+09
# max      1.503414e+09
# Name: CLOSETIME, dtype: float64
# count    8570.000000
# mean        2.158576
# std         2.944611
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        96.000000
# Name: all_num_of_repeat, dtype: float64
# count    1838.000000
# mean        1.057127
# std         0.243591
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: num_of_repeat2, dtype: float64
# count    4206.000000
# mean        1.091774
# std         0.329514
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000
# Name: num_of_repeat5, dtype: float64
# count    8570.000000
# mean        1.134539
# std         0.404473
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
# Name: num_of_repeat10, dtype: float64
# count    8570.000000
# mean        1.238040
# std         0.588964
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         9.000000
# Name: num_of_repeat30, dtype: float64
# count    8570.000000
# mean        1.348191
# std         0.805874
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        13.000000
# Name: num_of_repeat60, dtype: float64
# count    311.000000
# mean       1.070740
# std        0.515701
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        6.000000
# Name: MITYPE, dtype: float64
# count    250.000000
# mean       2.916000
# std        0.996452
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: MIPRIORITY, dtype: float64
# count    247.000000
# mean       2.919028
# std        0.967733
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: MIIMPACT, dtype: float64
# count    6216.000000
# mean        1.032819
# std         0.183514
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: NumWFMforEI, dtype: float64
# count    6216.000000
# mean       34.947716
# std         8.866544
# min         3.000000
# 25%        28.000000
# 50%        36.000000
# 75%        42.000000
# max        64.000000
# Name: TECHNICAL_DISTRICT, dtype: float64
# count    9637.000000
# mean        3.583999
# std         1.737114
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max         7.000000
# Name: EIDayOfWeek, dtype: float64
# count    9548.000000
# mean       14.297968
# std         4.089310
# min         1.000000
# 25%        11.000000
# 50%        14.000000
# 75%        17.000000
# max        23.000000
# Name: EIHourCreate, dtype: float64

# %%
# Cleaning the data
# dropped_data_without_empty_cols = data.dropna(axis=1)
# dropped_data_without_empty_rows = data.dropna(axis=0)
# data.count(axis=0)



for item in ['all_num_of_repeat', 'num_of_repeat2', 'num_of_repeat5', 'num_of_repeat10', 'num_of_repeat30', 'num_of_repeat60']:
    data[item]=data[item][data[item].isin([i for i in range(1000)] + [str(i) for i in range(1000)])]
    data[item]=data[item].replace(to_replace=[np.nan], value=[0])

    

# for col_name in ['SERVICE', 'channeltype', 'source']:
#     data[col_name]=data[col_name].replace(to_replace=[np.nan], value=[0])
#     data[col_name]=data[col_name].replace(to_replace=data[col_name].unique(), value=[i for i in range(len(data[col_name].unique()))])



# data['DECLARED_FAULT']=data['DECLARED_FAULT'].replace(to_replace=data['DECLARED_FAULT'].unique(), value=[i for i in range(1,len(data['DECLARED_FAULT'].unique())+1)]) 

# data['CLIENT_CATEGORY']=data['CLIENT_CATEGORY'][data['CLIENT_CATEGORY'].isin(['ФЛ', 'SOHO', 'NKA', 
# 'Выделенное обслуживание (пилот)', 'GS-SLA4', 'SME', 'Оператор', 'SME GS', 'Corporate', 'KA', 'SOHO_GS', 'GS-SLA1', 
# 'Corporate GS', 'GS-Имидж абоненты', 'Имидж-абоненты (физические лица)', 'GS-SLA3', 'INDIVIDUAL', 'KA GS', 'ФЛ_ИЗ_МРМ',
# 'Развитие', 'СПЕЦ', 'Внутренний', 'Посольства', 'Имидж-абоненты (юридические лица)', 'NKA GS'])]
# data['CLIENT_CATEGORY']=data['CLIENT_CATEGORY'].replace(to_replace=data['CLIENT_CATEGORY'].unique(), value=[i for i in range(1,len(data['CLIENT_CATEGORY'].unique())+1)]) 

# data['SEGMENT']=data['SEGMENT'][data['SEGMENT'].isin(['МР','КОРП','ГОС','Оператор','БС28','Внутренний','БС22'])]
# data['SEGMENT']=data['SEGMENT'].replace(to_replace=data['SEGMENT'].unique(), value=[i for i in range(1,len(data['SEGMENT'].unique())+1)]) 


data['DECLARED_FAULT']=data['DECLARED_FAULT'].map(data.groupby('DECLARED_FAULT').size())

data['CLIENT_CATEGORY']=data['CLIENT_CATEGORY'].map(data.groupby('CLIENT_CATEGORY').size())

data['SEGMENT']=data['SEGMENT'].map(data.groupby('SEGMENT').size())



for i in ['CREATE_DATE', 'CLOSETIME']:
    data[i] = pd.to_numeric(data[i],errors='coerce')

# %%
data['CLIENT_CATEGORY']
# Out:
# 0       7229.0
# 1       7229.0
# 2       7229.0
# 3         94.0
# 4        222.0
# 5       7229.0
# 6        222.0
# 7       7229.0
# 8        190.0
# 9       7229.0
# 10      7229.0
# 11      7229.0
# 12      7229.0
# 13      7229.0
# 14      7229.0
# 15      7229.0
# 16      7229.0
# 17      7229.0
# 18       229.0
# 19      7229.0
# 20       190.0
# 21      7229.0
# 22      7229.0
# 23      7229.0
# 24        26.0
# 25        94.0
# 26      7229.0
# 27      7229.0
# 28      7229.0
# 29       812.0
#          ...
# 9607    7229.0
# 9608    7229.0
# 9609      19.0
# 9610    7229.0
# 9611     812.0
# 9612    7229.0
# 9613    7229.0
# 9614     812.0
# 9615     812.0
# 9616    7229.0
# 9617     229.0
# 9618    7229.0
# 9619     812.0
# 9620    7229.0
# 9621    7229.0
# 9622     222.0
# 9623     222.0
# 9624    7229.0
# 9625    7229.0
# 9626    7229.0
# 9627    7229.0
# 9628       3.0
# 9629    7229.0
# 9630    7229.0
# 9631     812.0
# 9632    7229.0
# 9633      94.0
# 9634    7229.0
# 9635     229.0
# 9636    7229.0
# Name: CLIENT_CATEGORY, Length: 9637, dtype: float64

# %%
data['CREATE_DATE'].unique()
# Out:
# array([1502669034, 1502670676, 1502673214, ..., 1503412428, 1503412831,
#        1503413585], dtype=int64)

# %%
type(data['CREATE_DATE'].head()[1])
# Out:
# numpy.int64

# %%
# Generation of data
data['decision_time'] = data['CLOSETIME']-data['CREATE_DATE']

# %%
data['SEGMENT'].head()
# Out:
# 0    7478.0
# 1    7478.0
# 2    7478.0
# 3    1831.0
# 4    1831.0
# Name: SEGMENT, dtype: float64

# %%
# # Selecting data
# sel_data = pd.concat((data['CLIENT_CATEGORY'],
# data['SEGMENT'],
# data['SERVICE'],
# data['channeltype'],
# data['source'],
# # data['CHANNELREQUESTID'],
# data['football'],
# data['DECLARED_FAULT'],
# data['all_num_of_repeat'],
# data['num_of_repeat2'],
# data['num_of_repeat5'],
# data['num_of_repeat10'],
# data['num_of_repeat30'],
# data['num_of_repeat60'],
# data['CREATE_DATE'],
# data['CLOSETIME'],
# data['decision_time'],
# # data['TIMELEFTSLA']
#                      ), axis=1)
# sel_data.describe()

# %%
print(data['football'].unique()[2])
# for i in sel_data['SERVICE']:
#     if i.startswith('2'):
#         pass
#     else:
#         print(i)
# Out:
# 7

# %%
# # full list of categorical columns, where 'nan' is missing values
# for c in sel_data:
#     print(c, sel_data[c].unique(), len(sel_data[c].unique()))

# %%
# # for each numerical/quantitative feature built histogram,
# # for each pair of nemerical built dispersion (scattering) diagram
# from pandas.plotting import scatter_matrix
# scatter_matrix(data, alpha=0.05, figsize=(15, 15));

# %%
data[numerical_columns].corr() # matrix of correlations
# Out:
#                      Service  Channeltype    Source  football  CREATE_DATE  \
# Service             1.000000     0.001074 -0.348742  0.177788    -0.009712
# Channeltype         0.001074     1.000000  0.015264  0.108218    -0.000321
# Source             -0.348742     0.015264  1.000000 -0.180624    -0.003669
# football            0.177788     0.108218 -0.180624  1.000000    -0.065425
# CREATE_DATE        -0.009712    -0.000321 -0.003669 -0.065425     1.000000
# CLOSETIME          -0.025514     0.003305  0.005837 -0.009322     0.977863
# all_num_of_repeat  -0.124604    -0.009079  0.104101  0.001829     0.012896
# num_of_repeat2     -0.084942     0.017190  0.073025 -0.050662     0.641415
# num_of_repeat5     -0.172649     0.002723  0.126788 -0.094321     0.689299
# num_of_repeat10    -0.398771     0.013073  0.300238 -0.080205     0.008188
# num_of_repeat30    -0.324118     0.029636  0.252150 -0.040125    -0.011515
# num_of_repeat60    -0.273242     0.035488  0.213982 -0.022169    -0.003979
# MITYPE             -0.101676    -0.075002  0.024772  0.082708    -0.116414
# MIPRIORITY          0.514746     0.359948  0.043365 -0.077332     0.176642
# MIIMPACT            0.524018     0.290489  0.045377 -0.061278     0.170233
# NumWFMforEI        -0.017137     0.006723       NaN  0.013830    -0.039730
# TECHNICAL_DISTRICT  0.001374    -0.058202       NaN -0.025592    -0.008656
# EIDayOfWeek        -0.026749    -0.012744  0.023493 -0.030246     0.027881
# EIHourCreate       -0.085554     0.062043  0.060740 -0.069515    -0.018416
#
#                     CLOSETIME  all_num_of_repeat  num_of_repeat2  \
# Service             -0.025514          -0.124604       -0.084942
# Channeltype          0.003305          -0.009079        0.017190
# Source               0.005837           0.104101        0.073025
# football            -0.009322           0.001829       -0.050662
# CREATE_DATE          0.977863           0.012896        0.641415
# CLOSETIME            1.000000           0.006611        0.615430
# all_num_of_repeat    0.006611           1.000000        0.110284
# num_of_repeat2       0.615430           0.110284        1.000000
# num_of_repeat5       0.686302           0.156114        0.576168
# num_of_repeat10      0.021350           0.333323        0.251286
# num_of_repeat30     -0.000302           0.470294        0.209568
# num_of_repeat60      0.003667           0.595996        0.185761
# MITYPE              -0.102948           0.023575       -0.038400
# MIPRIORITY           0.050011          -0.143467       -0.011062
# MIIMPACT             0.047439          -0.189758       -0.012167
# NumWFMforEI         -0.010429          -0.007358       -0.030953
# TECHNICAL_DISTRICT  -0.004715          -0.005456        0.014540
# EIDayOfWeek          0.031427          -0.004084       -0.338143
# EIHourCreate         0.029689          -0.006522       -0.017933
#
#                     num_of_repeat5  num_of_repeat10  num_of_repeat30  \
# Service                  -0.172649        -0.398771        -0.324118
# Channeltype               0.002723         0.013073         0.029636
# Source                    0.126788         0.300238         0.252150
# football                 -0.094321        -0.080205        -0.040125
# CREATE_DATE               0.689299         0.008188        -0.011515
# CLOSETIME                 0.686302         0.021350        -0.000302
# all_num_of_repeat         0.156114         0.333323         0.470294
# num_of_repeat2            0.576168         0.251286         0.209568
# num_of_repeat5            1.000000         0.433863         0.347982
# num_of_repeat10           0.433863         1.000000         0.844944
# num_of_repeat30           0.347982         0.844944         1.000000
# num_of_repeat60           0.308829         0.723747         0.881671
# MITYPE                   -0.036553         0.070556         0.077298
# MIPRIORITY               -0.026456        -0.464899        -0.381279
# MIIMPACT                 -0.037761        -0.480757        -0.401769
# NumWFMforEI              -0.021404         0.017408         0.025920
# TECHNICAL_DISTRICT       -0.004508         0.017821         0.015483
# EIDayOfWeek               0.171595         0.041652         0.019371
# EIHourCreate              0.050144         0.067871         0.039688
#
#                     num_of_repeat60    MITYPE  MIPRIORITY  MIIMPACT  \
# Service                   -0.273242 -0.101676    0.514746  0.524018
# Channeltype                0.035488 -0.075002    0.359948  0.290489
# Source                     0.213982  0.024772    0.043365  0.045377
# football                  -0.022169  0.082708   -0.077332 -0.061278
# CREATE_DATE               -0.003979 -0.116414    0.176642  0.170233
# CLOSETIME                  0.003667 -0.102948    0.050011  0.047439
# all_num_of_repeat          0.595996  0.023575   -0.143467 -0.189758
# num_of_repeat2             0.185761 -0.038400   -0.011062 -0.012167
# num_of_repeat5             0.308829 -0.036553   -0.026456 -0.037761
# num_of_repeat10            0.723747  0.070556   -0.464899 -0.480757
# num_of_repeat30            0.881671  0.077298   -0.381279 -0.401769
# num_of_repeat60            1.000000  0.040801   -0.283034 -0.308548
# MITYPE                     0.040801  1.000000   -0.232743 -0.098449
# MIPRIORITY                -0.283034 -0.232743    1.000000  0.980997
# MIIMPACT                  -0.308548 -0.098449    0.980997  1.000000
# NumWFMforEI                0.017022 -0.038462    0.079138  0.079138
# TECHNICAL_DISTRICT         0.003763  0.011968    0.007346  0.007346
# EIDayOfWeek                0.017616 -0.068000    0.114911  0.124350
# EIHourCreate               0.029412  0.119092   -0.200978 -0.216035
#
#                     NumWFMforEI  TECHNICAL_DISTRICT  EIDayOfWeek  EIHourCreate
# Service               -0.017137            0.001374    -0.026749     -0.085554
# Channeltype            0.006723           -0.058202    -0.012744      0.062043
# Source                      NaN                 NaN     0.023493      0.060740
# football               0.013830           -0.025592    -0.030246     -0.069515
# CREATE_DATE           -0.039730           -0.008656     0.027881     -0.018416
# CLOSETIME             -0.010429           -0.004715     0.031427      0.029689
# all_num_of_repeat     -0.007358           -0.005456    -0.004084     -0.006522
# num_of_repeat2        -0.030953            0.014540    -0.338143     -0.017933
# num_of_repeat5        -0.021404           -0.004508     0.171595      0.050144
# num_of_repeat10        0.017408            0.017821     0.041652      0.067871
# num_of_repeat30        0.025920            0.015483     0.019371      0.039688
# num_of_repeat60        0.017022            0.003763     0.017616      0.029412
# MITYPE                -0.038462            0.011968    -0.068000      0.119092
# MIPRIORITY             0.079138            0.007346     0.114911     -0.200978
# MIIMPACT               0.079138            0.007346     0.124350     -0.216035
# NumWFMforEI            1.000000           -0.005076    -0.002062      0.019082
# TECHNICAL_DISTRICT    -0.005076            1.000000    -0.012654     -0.015011
# EIDayOfWeek           -0.002062           -0.012654     1.000000     -0.000188
# EIHourCreate           0.019082           -0.015011    -0.000188      1.000000

# %%
# Find the number of completed (not skipped) items
# axis = 0 means that we move counter from top to bottom, and axis = 1 than we move counter from left to right
data.count(axis=0)
# Out:
# CLIENT_CATEGORY       9591
# SEGMENT               9633
# Service               9637
# Channeltype           8632
# Source                9637
# football              9637
# DECLARED_FAULT        9637
# CREATE_DATE           9637
# CLOSETIME             9637
# all_num_of_repeat     9637
# num_of_repeat2        9637
# num_of_repeat5        9637
# num_of_repeat10       9637
# num_of_repeat30       9637
# num_of_repeat60       9637
# MITYPE                 311
# MIPRIORITY             250
# MIIMPACT               247
# NumWFMforEI           6216
# TECHNICAL_DISTRICT    6216
# EIDayOfWeek           9637
# EIHourCreate          9548
# decision_time         9637
# dtype: int64

# %%
# fill the missing values
# fill all numerical features (Instead of gaps (missing values), we substitute the median values (data.median(axis=0)))
data = data.fillna(0, axis=0)

# %%
# before
# data['A1'].describe()

# %%
# # fill the missing values in categorical feature with top value (Instead missing values) we substitute 
# # the top value in this column
# data['A1'] = data['A1'].fillna('b')

# %%
# result
data.describe()
# Out:
#        CLIENT_CATEGORY      SEGMENT      Service   Channeltype        Source  \
# count      9637.000000  9637.000000  9637.000000   9637.000000   9637.000000
# mean       5515.529003  6157.700841  8793.888555   8319.609318   8689.607243
# std        2973.316965  2472.772882   314.066338   2854.979982    388.953144
# min           0.000000     0.000000  8676.000000      0.000000   7470.000000
# 25%        7229.000000  7478.000000  8678.000000   9204.000000   8750.000000
# 50%        7229.000000  7478.000000  8678.000000   9204.000000   8750.000000
# 75%        7229.000000  7478.000000  8680.000000   9204.000000   8750.000000
# max        7229.000000  7478.000000  9650.000000  10769.000000  10867.000000
#
#           football  DECLARED_FAULT   CREATE_DATE     CLOSETIME  \
# count  9637.000000     9637.000000  9.637000e+03  9.637000e+03
# mean      3.436962      369.243437  1.502999e+09  1.503047e+09
# std       1.462090      302.539221  2.180252e+05  2.162802e+05
# min       1.000000        1.000000  1.502669e+09  1.502686e+09
# 25%       3.000000      111.000000  1.502804e+09  1.502875e+09
# 50%       3.000000      300.000000  1.502967e+09  1.503023e+09
# 75%       4.000000      751.000000  1.503176e+09  1.503234e+09
# max      29.000000      932.000000  1.503414e+09  1.503414e+09
#
#        all_num_of_repeat      ...        num_of_repeat30  num_of_repeat60  \
# count        9637.000000      ...            9637.000000      9637.000000
# mean            1.919581      ...               1.100965         1.198921
# std             2.858222      ...               0.677789         0.869772
# min             0.000000      ...               0.000000         0.000000
# 25%             1.000000      ...               1.000000         1.000000
# 50%             1.000000      ...               1.000000         1.000000
# 75%             2.000000      ...               1.000000         1.000000
# max            96.000000      ...               9.000000        13.000000
#
#             MITYPE   MIPRIORITY     MIIMPACT  NumWFMforEI  TECHNICAL_DISTRICT  \
# count  9637.000000  9637.000000  9637.000000  9637.000000         9637.000000
# mean      0.034554     0.075646     0.074816     0.666182           22.541766
# std       0.210628     0.490450     0.486541     0.515745           18.176532
# min       0.000000     0.000000     0.000000     0.000000            0.000000
# 25%       0.000000     0.000000     0.000000     0.000000            0.000000
# 50%       0.000000     0.000000     0.000000     1.000000           28.000000
# 75%       0.000000     0.000000     0.000000     1.000000           39.000000
# max       6.000000     5.000000     4.000000     3.000000           64.000000
#
#        EIDayOfWeek  EIHourCreate  decision_time
# count  9637.000000   9637.000000    9637.000000
# mean      3.583999     14.165923   48691.047318
# std       1.737114      4.294035   45724.596552
# min       1.000000      0.000000      30.000000
# 25%       2.000000     11.000000    7774.000000
# 50%       3.000000     14.000000   33615.000000
# 75%       5.000000     17.000000   80996.000000
# max       7.000000     23.000000  172777.000000
#
# [8 rows x 23 columns]

# %%
try:
    data_describe = data.describe(include=[object])
    data_describe
except:
    pass

# %%
# for c in categorical_columns:
#     data[c] = data[c].fillna(data_describe[c]['top'])
# data.describe(include=[object])

# %%
# data['DECLARED_FAULT'].unique()

# %%
# # devide categorical (non-numerical) columns to binary and nonbinary
# binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
# nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
# print(binary_columns, nonbinary_columns)

# %%
# # for non-binary columns|features vectorizing is 1) divide each column to the numbers of unique values in the column
# # 2) and if value exist then only one column's row filled like 1
# # for example, column A4 have 3 unique values: print(data['A4'].unique()) => ['u' 'y' 'l']
# # create 3 new columns: 4_u, A4_y, A4_l
# # If A4 value is 'u', then A4_u = 1, A4_y = 0, A4_l = 0, etc.
# # In Pandas it's performed via using .get_dummies method.

# data_nonbinary = pd.get_dummies(data[nonbinary_columns[6:8]], columns=None) # !!!!!! Limitation 6:10!!!!!!!!!1
# data_nonbinary.columns

# %%
# data = data_nonbinary
# data = pd.DataFrame(data, dtype=float)
# print(data.shape)
# print(data.columns)

# %%
# Normalization
data_numerical = data[numerical_columns]
data_numerical = (data_numerical - data_numerical.mean()) / data_numerical.std()
data_numerical.describe()
# Out:
#             Service   Channeltype        Source      football   CREATE_DATE  \
# count  9.637000e+03  9.637000e+03  9.637000e+03  9.637000e+03  9.637000e+03
# mean   3.299218e-15 -1.630589e-15  1.238445e-17  6.738536e-15 -2.028603e-13
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.753620e-01 -2.914069e+00 -3.135615e+00 -1.666766e+00 -1.512139e+00
# 25%   -3.689939e-01  3.097712e-01  1.552700e-01 -2.988610e-01 -8.950037e-01
# 50%   -3.689939e-01  3.097712e-01  1.552700e-01 -2.988610e-01 -1.471496e-01
# 75%   -3.626258e-01  3.097712e-01  1.552700e-01  3.850913e-01  8.134413e-01
# max    2.725894e+00  8.579362e-01  5.598085e+00  1.748390e+01  1.902839e+00
#
#           CLOSETIME  all_num_of_repeat  num_of_repeat2  num_of_repeat5  \
# count  9.637000e+03       9.637000e+03    9.637000e+03    9.637000e+03
# mean   3.720308e-13      -7.766960e-17   -3.882225e-14   -4.715391e-14
# std    1.000000e+00       1.000000e+00    1.000000e+00    1.000000e+00
# min   -1.671852e+00      -6.715995e-01   -4.702608e-01   -8.164771e-01
# 25%   -7.952804e-01      -3.217317e-01   -4.702608e-01   -8.164771e-01
# 50%   -1.136876e-01      -3.217317e-01   -4.702608e-01   -8.164771e-01
# 75%    8.621763e-01       2.813610e-02   -4.702608e-01    8.970224e-01
# max    1.693487e+00       3.291571e+01    6.527017e+00    6.037521e+00
#
#        num_of_repeat10  num_of_repeat30  num_of_repeat60        MITYPE  \
# count     9.637000e+03     9.637000e+03     9.637000e+03  9.637000e+03
# mean     -7.112247e-16     4.820144e-16    -8.365439e-16 -4.221751e-15
# std       1.000000e+00     1.000000e+00     1.000000e+00  1.000000e+00
# min      -1.933697e+00    -1.624347e+00    -1.378431e+00 -1.640537e-01
# 25%      -1.710356e-02    -1.489623e-01    -2.287045e-01 -1.640537e-01
# 50%      -1.710356e-02    -1.489623e-01    -2.287045e-01 -1.640537e-01
# 75%      -1.710356e-02    -1.489623e-01    -2.287045e-01 -1.640537e-01
# max       7.649270e+00     1.165412e+01     1.356801e+01  2.832217e+01
#
#          MIPRIORITY      MIIMPACT   NumWFMforEI  TECHNICAL_DISTRICT  \
# count  9.637000e+03  9.637000e+03  9.637000e+03        9.637000e+03
# mean  -4.304099e-15 -3.664514e-15  2.222796e-15        1.128587e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00        1.000000e+00
# min   -1.542379e-01 -1.537707e-01 -1.291689e+00       -1.240158e+00
# 25%   -1.542379e-01 -1.537707e-01 -1.291689e+00       -1.240158e+00
# 50%   -1.542379e-01 -1.537707e-01  6.472530e-01        3.002902e-01
# 75%   -1.542379e-01 -1.537707e-01  6.472530e-01        9.054661e-01
# max    1.004048e+01  8.067524e+00  4.525137e+00        2.280866e+00
#
#         EIDayOfWeek  EIHourCreate
# count  9.637000e+03  9.637000e+03
# mean   2.425310e-14 -3.424100e-16
# std    1.000000e+00  1.000000e+00
# min   -1.487524e+00 -3.298977e+00
# 25%   -9.118568e-01 -7.372839e-01
# 50%   -3.361893e-01 -3.864035e-02
# 75%    8.151457e-01  6.600032e-01
# max    1.966481e+00  2.057290e+00

# %%
# data_numerical.head()

# %%
X = data.drop(['all_num_of_repeat','CLOSETIME', 'CREATE_DATE'], axis=1)  
y = data['all_num_of_repeat']
feature_names = X.columns
print(feature_names)
# Out:
# Index(['CLIENT_CATEGORY', 'SEGMENT', 'Service', 'Channeltype', 'Source',
#        'football', 'DECLARED_FAULT', 'num_of_repeat2', 'num_of_repeat5',
#        'num_of_repeat10', 'num_of_repeat30', 'num_of_repeat60', 'MITYPE',
#        'MIPRIORITY', 'MIIMPACT', 'NumWFMforEI', 'TECHNICAL_DISTRICT',
#        'EIDayOfWeek', 'EIHourCreate', 'decision_time'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (9637, 20)
# (9637,)

# %%
# %%time
# Devide for train and test samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 11)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 
print(N_train, N_test)
# X_train, y_train is a training sample, X_test, y_test is a test sample.
# Out:
# 7227 2410
# Wall time: 4.27 s

# %%
# %%time
# Teach the model
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# Wall time: 439 ms

# %%
# %%time
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)
print(err_train, err_test)
# Out:
# 0.362252663623 0.46265560166
# Wall time: 281 ms

# %%
# %%time
# from sklearn.model_selection import GridSearchCV
# n_neighbors_array = [1, 3, 5, 7, 10, 15, 20, 40, 60, 235]
# knn = KNeighborsClassifier()
# grid = GridSearchCV(knn, param_grid={'n_neighbors': n_neighbors_array})
# grid.fit(X_train, y_train)

# best_cv_err = 1 - grid.best_score_
# best_n_neighbors = grid.best_estimator_.n_neighbors
# print(best_cv_err, best_n_neighbors)

# %%
# %%time
# knn = KNeighborsClassifier(n_neighbors=best_n_neighbors)
# knn.fit(X_train, y_train)

# err_train = np.mean(y_train != knn.predict(X_train))
# err_test  = np.mean(y_test  != knn.predict(X_test))
# print(err_train, err_test)

# %%
# %%time
# from sklearn.svm import SVC
# svc = SVC()
# svc.fit(X_train, y_train)

# err_train = np.mean(y_train != svc.predict(X_train))
# err_test  = np.mean(y_test  != svc.predict(X_test))
# print(err_train, err_test)

# %%
# %%time
# from sklearn.model_selection import GridSearchCV
# C_array = np.logspace(-3, 3, num=7)
# gamma_array = np.logspace(-5, 2, num=8)
# svc = SVC(kernel='rbf')
# grid = GridSearchCV(svc, param_grid={'C': C_array, 'gamma': gamma_array, 'n'})
# grid.fit(X_train, y_train)
# print('CV error    = ', 1 - grid.best_score_)
# print('best C      = ', grid.best_estimator_.C)
# print('best gamma  = ', grid.best_estimator_.gamma)

# %%
# %%time
# svc = SVC(kernel='rbf', C=grid.best_estimator_.C, gamma=grid.best_estimator_.gamma)
# svc.fit(X_train, y_train)

# err_train = np.mean(y_train != svc.predict(X_train))
# err_test  = np.mean(y_test  != svc.predict(X_test))
# print(err_train, err_test)

# %%
# %%time
# from sklearn.model_selection import GridSearchCV
# C_array = np.logspace(-3, 3, num=7)
# svc = SVC(kernel='linear')
# grid = GridSearchCV(svc, param_grid={'C': C_array})
# grid.fit(X_train, y_train)
# print('CV error    = ', 1 - grid.best_score_)
# print('best C      = ', grid.best_estimator_.C)

# %%
# %%time
# svc = SVC(kernel='linear', C=grid.best_estimator_.C)
# svc.fit(X_train, y_train)

# err_train = np.mean(y_train != svc.predict(X_train))
# err_test  = np.mean(y_test  != svc.predict(X_test))
# print(err_train, err_test)

# %%
# %%time
# from sklearn.grid_search import GridSearchCV
# C_array = np.logspace(-5, 2, num=8)
# gamma_array = np.logspace(-5, 2, num=8)
# degree_array = [2, 3, 4]
# svc = SVC(kernel='poly')
# grid = GridSearchCV(svc, param_grid={'C': C_array, 'gamma': gamma_array, 'degree': degree_array})
# grid.fit(X_train, y_train)
# print('CV error    = ', 1 - grid.best_score_)
# print('best C      = ', grid.best_estimator_.C)
# print('best gamma  = ', grid.best_estimator_.gamma)
# print('best degree = ', grid.best_estimator_.degree)

# %%
# %%time
# svc = SVC(kernel='poly', C=grid.best_estimator_.C, 
#           gamma=grid.best_estimator_.gamma, degree=grid.best_estimator_.degree)
# svc.fit(X_train, y_train)

# err_train = np.mean(y_train != svc.predict(X_train))
# err_test  = np.mean(y_test  != svc.predict(X_test))
# print(err_train, err_test)

# %%
# %%time
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators=2, random_state=11)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))
print(err_train, err_test)
# Out:
# 0.144596651446 0.347302904564
# Wall time: 431 ms

# %%
# %%time
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature importances:")
for f, idx in enumerate(indices):
    print("{:2d}. feature '{:5s}' ({:.4f})".format(f + 1, feature_names[idx], importances[idx]))
# Out:
# Feature importances:
#  1. feature 'num_of_repeat60' (0.2394)
#  2. feature 'decision_time' (0.1637)
#  3. feature 'EIHourCreate' (0.1034)
#  4. feature 'DECLARED_FAULT' (0.0971)
#  5. feature 'TECHNICAL_DISTRICT' (0.0773)
#  6. feature 'Source' (0.0730)
#  7. feature 'EIDayOfWeek' (0.0530)
#  8. feature 'Channeltype' (0.0374)
#  9. feature 'football' (0.0282)
# 10. feature 'Service' (0.0274)
# 11. feature 'num_of_repeat5' (0.0252)
# 12. feature 'CLIENT_CATEGORY' (0.0229)
# 13. feature 'num_of_repeat2' (0.0139)
# 14. feature 'num_of_repeat30' (0.0113)
# 15. feature 'NumWFMforEI' (0.0092)
# 16. feature 'SEGMENT' (0.0073)
# 17. feature 'num_of_repeat10' (0.0072)
# 18. feature 'MIPRIORITY' (0.0014)
# 19. feature 'MITYPE' (0.0009)
# 20. feature 'MIIMPACT' (0.0008)
# Wall time: 1 ms

# %%
# %%time

data_period = url_to_data.split('.')[0].split('/')[1][4:]

plt.subplots_adjust(left=0.15)
d_first = 20
plt.figure(figsize=(8, 8))
plt.title("Вклад признаков в повторку (по данным за {0})".format(data_period))
plt.bar(range(d_first), importances[indices[:d_first]], align='center')
plt.xticks(range(d_first), np.array(feature_names)[indices[:d_first]], rotation=90)
plt.xlim([-1, d_first])
plt.savefig("FeaturesImportances{0}.pdf".format(data_period))

# %%
# %%time
print(len(feature_names))
best_features = indices[:8]
best_features_names = feature_names[best_features]
print(best_features_names)
# Out:
# 20
# Index(['num_of_repeat60', 'decision_time', 'EIHourCreate', 'DECLARED_FAULT',
#        'TECHNICAL_DISTRICT', 'Source', 'EIDayOfWeek', 'Channeltype'],
#       dtype='object')
# Wall time: 0 ns

# %%
# %%time
# from sklearn import ensemble
# gbt = ensemble.GradientBoostingClassifier(n_estimators=100, random_state=11)
# gbt.fit(X_train, y_train)

# err_train = np.mean(y_train != gbt.predict(X_train))
# err_test = np.mean(y_test != gbt.predict(X_test))
# print(err_train, err_test)

# %%
# %%time
gbt = ensemble.GradientBoostingClassifier(n_estimators=100, random_state=11)
gbt.fit(X_train[best_features_names], y_train)

err_train = np.mean(y_train != gbt.predict(X_train[best_features_names]))
err_test = np.mean(y_test != gbt.predict(X_test[best_features_names]))
print(err_train, err_test)
# Out:
# 0.253632212536 0.297925311203
# Wall time: 31.3 s
